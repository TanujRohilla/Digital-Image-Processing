# %% [markdown]
# ## Program 1 - Negative of a Image

# %%
from matplotlib.image import *
from matplotlib.pyplot import *
import numpy as np
import math as mt

# %%
img=imread(r"C:\Users\DUCS-29\Desktop\graylevel6.jpg")
imshow(img)

# %%
negative=255-img
imshow(negative)

# %% [markdown]
# ## Program 2 - Add Value to Image

# %%
value = 70
addValueImage=img+value
imshow(addValueImage)

# %% [markdown]
# ## Program 3 - Log Transformation of Image

# %%
'''
    s = c log(r + 1)
        
'''
c = 60
one=np.ones(img.shape)
temp=np.add(img,one)
s=(c*np.log(temp)).astype(int)
imshow(s)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Program 4 - Power Law Transformation

# %%
'''
    s=cr^γ
'''

gamma=2
temp=(c*img**(1/gamma))
img2=temp.astype(int)
imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
gamma=0.5
temp=(c*img**(1/gamma))
img2=temp.astype(int)
imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
